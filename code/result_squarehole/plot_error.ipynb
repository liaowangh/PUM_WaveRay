# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
def compute_rate(ndofs, err):
    lin_reg = stats.linregress(np.log(ndofs), np.log(err))
    return lin_reg.slope

# %%
def plot_save(ndofs, L2err, H1err, output_folder, sol_name, show_rate=True):
    if show_rate:
        l2_rate = compute_rate(ndofs, L2err)
        l2_rate = round(abs(l2_rate), 1)
        h1_rate = compute_rate(ndofs, H1err)
        h1_rate = round(abs(h1_rate), 1)

        l2_label = 'L2 norm, rate=' + repr(l2_rate)
        h1_label = 'H1 semi norm, rate=' + repr(h1_rate)
    else:
        l2_label = 'L2 norm'
        h1_label = 'H1 semi norm'
    
    fig,ax = plt.subplots()
    ax.loglog(ndofs, L2err, '^-', label=l2_label) # triangle marker
    ax.loglog(ndofs, H1err, 's-', label=h1_label) # square marker
#     ax.set_xlabel('Dofs[log]')
    ax.set_xlabel('Mesh width [log]')
    ax.set_ylabel('Discretization err[log]')
#     ax.set_title(sol_name)
    ax.legend()
#     fig.savefig(output_folder + sol_name+'.eps', format='eps')

# %% [markdown]
# # Test manufacture solutions in Lagrangian finite element spaces
#
# ## Solve in single mesh directly(domain: unit square)

# %%
folder = "../result_square/LagrangeO1/k6_"
data_file = ["plan_wave.txt", "fundamental_sol.txt", "spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
    mesh_width = df['h'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1serr = df['H1_serr'].to_numpy()
#     plot_save(mesh_width, L2err, H1serr, folder, sol_name)
    plot_save(mesh_width[1:], L2err[1:], H1serr[1:], folder, sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
folder = "../result_square/LagrangeO1/k2_"
data_file = ["plane_wave.txt", "fundamental_sol.txt", "spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
    mesh_width = df['h'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1serr = df['H1_serr'].to_numpy()
#     plot_save(mesh_width, L2err, H1serr, folder, sol_name)
    plot_save(mesh_width[2:], L2err[2:], H1serr[2:], folder, sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## unit square with a hole inside

# %%
folder = "LagrangeO1/k2_"
data_file = ["plane_wave.txt", "fundamental_sol.txt", "spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
    mesh_width = df['h'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1serr = df['H1_serr'].to_numpy()
#     plot_save(mesh_width, L2err, H1serr, folder, sol_name)
    plot_save(mesh_width[2:], L2err[2:], H1serr[2:], folder, sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Using two grid, still Lagrangian finite element space

# %%
folder = "LagrangeO1/2grids_"
data_file = ["plan_wave.txt", "fundamental_sol.txt", "spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
    ndofs = df['N'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1err = df['H1_err'].to_numpy()
#     plot_save(ndofs, L2err, H1err, folder, sol_name)
    plot_save(ndofs[1:], L2err[1:], H1err[1:], folder, sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Test manufacture solutions in Lagrangian finite element spaces
#
# ## h-version, number of plan waves is 3 in all mesh

# %%
folder = "planwave_PUM/"
data_file = ["h_plan_wave.txt", "h_fundamental_sol.txt", "h_spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
#     ndofs = df['N'].to_numpy()
    mesh_width = df['h'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1err = df['H1_err'].to_numpy()
    plot_save(mesh_width, L2err, H1err, folder, sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # p-version, number of plan waves: 3, 5, 7, 9. Number of vertices in mesh: 120

# %%
folder = "planwave_PUM/"
data_file = ["p_plan_wave.txt", "p_fundamental_sol.txt", "p_spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
    ndofs = df['N'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1err = df['H1_err'].to_numpy()
    plot_save(ndofs, L2err, H1err, folder, sol_name, False)
#     plot_save(ndofs[:3], L2err[:3], H1err[:3], folder, sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## h-version, number of plan waves is 5 in all mesh

# %%
data_file = ["pum5_plan_wave.txt", "pum5_fundamental_sol.txt", "pum5_spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(f, sep=' ')
    ndofs = df['N'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1err = df['H1_err'].to_numpy()
    plot_save(ndofs, L2err, H1err, sol_name)

# %% [markdown]
# # Compute FE solution on finest mesh (Lagrange FEM) and coarser mesh (PW-PUM FEM)
# mesh vertices num_planwav
#
# 0    12       16
#
# 1    36       8
#
# 2   120       4
#
# 3   432
#
# ## the coarser space can still resolve solutions

# %%
folder = "pum_waveray/"
data_file = ["waveray_plan_wave.txt", "waveray_fundamental_sol.txt", "waveray_spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
    ndofs = df['N'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1err = df['H1_err'].to_numpy()
    plot_save(ndofs, L2err, H1err, folder, sol_name, False)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # PUM wave ray multigrid

# %%
folder = "pum_waveray/2grids_k2_"
data_file = ["waveray_plan_wave.txt", "waveray_fundamental_sol.txt", "waveray_spherical_wave.txt"]
for f in data_file:
    sol_name = f.split('.')[0]
    df = pd.read_csv(folder + f, sep=' ')
    ndofs = df['N'].to_numpy()
    L2err = df['L2_err'].to_numpy()
    H1err = df['H1_err'].to_numpy()
    plot_save(ndofs, L2err, H1err, folder, sol_name, False)
#     plot_save(ndofs[1:], L2err[1:], H1err[1:], folder, sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Plot Eigenvalue

# %%
folder = "eigenvalues/"
data_file = ["k2_Galerkin", "k20_Galerkin", "k20", "k2"]
for f in data_file:
    name_str = f.split('.')[0]
    df = pd.read_csv(folder + f)
    eivals = df['EigenValues'].to_numpy()
    index = [i+1 for i in range(len(eivals))]
        
    fig,ax = plt.subplots()
    ax.plot(index, eivals, 'bo')
    ax.set_xlabel('Index')
    ax.set_ylabel('EigenValue')
    ax.set_title(f)
    fig.savefig(folder + f +'.eps', format='eps')

# %% [markdown]
# # Test the Laplace equation

# %%
data_file = "../result_square/Laplace/Harmonic.txt"

sol_name = "Harmonic_function"
df = pd.read_csv(data_file, sep=' ')
mesh_width = df['h'].to_numpy()
L2err = df['L2_err'].to_numpy()
H1serr = df['H1_serr'].to_numpy()
plot_save(mesh_width, L2err, H1serr, "../result_square/Laplace/", sol_name)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
